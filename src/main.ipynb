# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Proyecto individual Modulo 1

# %%
'''
Importar librerias y todo lo necesario
'''
try:
    # Variables de entorno
    from dotenv import load_dotenv
    load_dotenv()

    # Función básica custom para logging
    from log_gen import log
    from agent import Agent
    
    log('Librerias cargadas')
except Exception as err:
    log('Error cargando librerias:')
    log(str(err))
# Out:
# [2026-02-15 13:59:57 INFO] Librerias cargadas

# %%
agente = Agent()
# Out:
# [2026-02-15 13:59:59 INFO] Agente inicializado exitosamente.

# %%
agente.query_model('Hola!')
# Out:
# [{'role': 'system', 'content': 'Responde con frases cortas, no mas de 10 palabras'}, {'role': 'user', 'content': 'Hola!'}]
# [2026-02-15 14:00:00 INFO] Consultando API...
# [2026-02-15 14:00:02 INFO] Respuesta de API recibida.
# ¡Hola! ¿Cómo estás?
